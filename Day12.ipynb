# %% [markdown]
# ### Pandas

# %%
import pandas as pd
# version check
pd.__version__
# Out:
# '0.25.1'

# %% [markdown]
# - series -->1d array
# - DataFrame-->2d array
# - Pannel-->3d array

# %%
pd.Series([56,12,49])
# Out:
# 0    56
# 1    12
# 2    49
# dtype: int64

# %%
pd.Series([56,12,49],index=['raj','hari','sam'])
# Out:
# raj     56
# hari    12
# sam     49
# dtype: int64

# %%
pd.Series([56,12,49],index=[0,1,2])
# Out:
# 0    56
# 1    12
# 2    49
# dtype: int64

# %%
import numpy as np
np.array([56,12,49])
# Out:
# array([56, 12, 49])

# %%
s = pd.Series([56,12,49],index=['raj','hari','sam'])
print(s[0],s['raj'])
# Out:
# 56 56

# %% [markdown]
# Try to convert a tuple and numpy array to series

# %%
d ={'raj':56,'hari':12,'sam':49}
pd.Series(d)
# Out:
# raj     56
# hari    12
# sam     49
# dtype: int64

# %% [markdown]
# To access the indices of a series use the index of attribute

# %%
s.index
# Out:
# Index(['raj', 'hari', 'sam'], dtype='object')

# %% [markdown]
# ### Dataframe

# %%
d2 = {'namae':['hari','raju','sita'],
     'lamguage':['py','r','c'],
     }
pd.DataFrame(d2)
# Out:
#   namae lamguage
# 0  hari       py
# 1  raju        r
# 2  sita        c

# %%
help(pd.DataFrame.where)
# Out:
# Help on function where in module pandas.core.generic:
#
# where(self, cond, other=nan, inplace=False, axis=None, level=None, errors='raise', try_cast=False)
#     Replace values where the condition is False.
#
#     Parameters
#     ----------
#     cond : boolean Series/DataFrame, array-like, or callable
#         Where `cond` is True, keep the original value. Where
#         False, replace with corresponding value from `other`.
#         If `cond` is callable, it is computed on the Series/DataFrame and
#         should return boolean Series/DataFrame or array. The callable must
#         not change input Series/DataFrame (though pandas doesn't check it).
#
#         .. versionadded:: 0.18.1
#             A callable can be used as cond.
#
#     other : scalar, Series/DataFrame, or callable
#         Entries where `cond` is False are replaced with
#         corresponding value from `other`.
#         If other is callable, it is computed on the Series/DataFrame and
# ...

# %%
pd.DataFrame(d2,index=[423,415,472])
# Out:
#     namae lamguage
# 423  hari       py
# 415  raju        r
# 472  sita        c

# %%
data= pd.read_csv('https://raw.githubusercontent.com/sumathi16/Machine-Learning-with-Python/master/data/Student%20Data%20ML%20Jan%20(Responses)%20-%20Form%20responses%201.csv')
data
# Out:
#               Timestamp                       Name  \
# 0   30/01/2020 15:00:07              Sai Naga Raju
# 1   30/01/2020 15:00:20                   R deepak
# 2   30/01/2020 15:00:23              P K CHAITANYA
# 3   30/01/2020 15:00:25                 B SRIKANTH
# 4   30/01/2020 15:00:28           Himaja cherukuri
# 5   30/01/2020 15:00:28              M.Geethanjali
# 6   30/01/2020 15:00:33                  M.Nikhita
# 7   30/01/2020 15:00:37           DASARI PAVAN SAI
# 8   30/01/2020 15:00:39              B Jagan Mohan
# 9   30/01/2020 15:00:41          k.parameswara rao
# 10  30/01/2020 15:00:43           B.Ravindra kumar
# 11  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 12  30/01/2020 15:00:45      Thatavarti kavya sree
# 13  30/01/2020 15:01:10               Harish Bandi
# 14  30/01/2020 15:01:16     M.Bhavani Sankar Reddy
# 15  30/01/2020 15:01:24             Devendra Kumar
# 16  30/01/2020 15:01:35                    M.Ramya
# ...

# %%
data.head()
# Out:
#              Timestamp              Name                            MailId  \
# 0  30/01/2020 15:00:07     Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 1  30/01/2020 15:00:20          R deepak            deepakrella9@gmail.com
# 2  30/01/2020 15:00:23     P K CHAITANYA              chaitu1495@gmail.com
# 3  30/01/2020 15:00:25        B SRIKANTH           srikanthbisai@gmail.com
# 4  30/01/2020 15:00:28  Himaja cherukuri         himajacherukuri@gmail.com
#
#   Branch Qualification    RollNumber
# 0     IT        B.Tech    161FA07039
# 1    MCA            PG  121722501019
# 2    MCA            PG  121722501015
# 3    MCA            PG  121722501002
# 4    cse         BTech    161fa04079

# %%
data.shape
# Out:
# (26, 6)

# %%
data.shape[0]
# Out:
# 26

# %%
data.tail()
# Out:
#               Timestamp                       Name  \
# 21  30/01/2020 15:02:41           G. Vineeth Kumar
# 22  30/01/2020 15:02:49  JAYA NAVEEN KUMAR DUPPATI
# 23  30/01/2020 15:02:59                   vikram S
# 24  30/01/2020 15:04:10            SAI TEJA JALADI
# 25  30/01/2020 15:07:38         SAIKUMAR MANIKONDA
#
#                            MailId                  Branch Qualification  \
# 21          121822502016@gitam.in            Data Science          M.Sc
# 22    duppatijayanaveen@gmail.com                     I.T        B.TECH
# 23  vikramsabbavarapu60@gmail.com       civil engineering        B-tech
# 24    saitejajaladi2000@gmail.com                     I.T        B.TECH
# 25          saikumarm64@gmail.com  Automobile Engineering           B.E
#
#       RollNumber
# 21  121822502016
# 22    161FA07012
# 23    133J1A0150
# 24    161FA07025
# 25  245112769310

# %%
data.sample()
# Out:
#               Timestamp     Name                      MailId  \
# 16  30/01/2020 15:01:35  M.Ramya  ramya.marripoodi@gmail.com
#
#                     Branch Qualification  RollNumber
# 16  Information Technology        B.Tech  161FA07002

# %%
data.size
# Out:
# 156

# %%
type(data[['Name','MailId']])
# Out:
# pandas.core.frame.DataFrame

# %%
data['MailId']
# Out:
# 0     sainagarajusakhamuri99@gmail.com
# 1               deepakrella9@gmail.com
# 2                 chaitu1495@gmail.com
# 3              srikanthbisai@gmail.com
# 4            himajacherukuri@gmail.com
# 5              geethamuppuri@gmail.com
# 6               muvvanikhita@gmail.com
# 7             pavandasari226@gmail.com
# 8              bjaganmohan24@gmail.com
# 9       parameshkarumuri1997@gmail.com
# 10      ravindrakumarroyal12@gmail.com
# 11       bhargavperumalla123@gmail.com
# 12           kavyathatavarti@gmail.com
# 13             harishbandi12@gmail.com
# 14         bhavanisankar5758@gmail.com
# 15            devendra108148@gmail.com
# 16          ramya.marripoodi@gmail.com
# 17              tvnagajyothi@gmail.com
# 18           p.anandalakshmi@gmail.com
# 19             saikamavarapu@gmail.com
# 20               ali95asghar@gmail.com
# 21               121822502016@gitam.in
# 22         duppatijayanaveen@gmail.com
# 23       vikramsabbavarapu60@gmail.com
# ...

# %%
data.columns
# Out:
# Index(['Timestamp', 'Name', 'MailId', 'Branch', 'Qualification', 'RollNumber'], dtype='object')

# %%
# to get the row labels
data.index
# Out:
# RangeIndex(start=0, stop=26, step=1)

# %%
# to check the dtypes of all the columns
#output type-Series
data.dtypes
# Out:
# Timestamp        object
# Name             object
# MailId           object
# Branch           object
# Qualification    object
# RollNumber       object
# dtype: object

# %%
data.isnull()
# output type - DataFrame
# Out:
#     Timestamp   Name  MailId  Branch  Qualification  RollNumber
# 0       False  False   False   False          False       False
# 1       False  False   False   False          False       False
# 2       False  False   False   False          False       False
# 3       False  False   False   False          False       False
# 4       False  False   False   False          False       False
# 5       False  False   False   False          False       False
# 6       False  False   False   False          False       False
# 7       False  False   False   False          False       False
# 8       False  False   False   False          False       False
# 9       False  False   False   False          False       False
# 10      False  False   False   False          False       False
# 11      False  False   False   False          False       False
# 12      False  False   False   False          False       False
# 13      False  False   False   False          False       False
# ...

# %%
data.isnull().sum()
# Missing the
# Out:
# Timestamp        0
# Name             0
# MailId           0
# Branch           0
# Qualification    0
# RollNumber       0
# dtype: int64

# %%
print(True+False)
print(True+True)
print(False+True)
print(False+False)
# Out:
# 1
# 2
# 1
# 0

# %%
data
# Out:
#               Timestamp                       Name  \
# 0   30/01/2020 15:00:07              Sai Naga Raju
# 1   30/01/2020 15:00:20                   R deepak
# 2   30/01/2020 15:00:23              P K CHAITANYA
# 3   30/01/2020 15:00:25                 B SRIKANTH
# 4   30/01/2020 15:00:28           Himaja cherukuri
# 5   30/01/2020 15:00:28              M.Geethanjali
# 6   30/01/2020 15:00:33                  M.Nikhita
# 7   30/01/2020 15:00:37           DASARI PAVAN SAI
# 8   30/01/2020 15:00:39              B Jagan Mohan
# 9   30/01/2020 15:00:41          k.parameswara rao
# 10  30/01/2020 15:00:43           B.Ravindra kumar
# 11  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 12  30/01/2020 15:00:45      Thatavarti kavya sree
# 13  30/01/2020 15:01:10               Harish Bandi
# 14  30/01/2020 15:01:16     M.Bhavani Sankar Reddy
# 15  30/01/2020 15:01:24             Devendra Kumar
# 16  30/01/2020 15:01:35                    M.Ramya
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
tsv_data= pd.read_csv('https://raw.githubusercontent.com/sumathi16/Machine-Learning-with-Python/master/data/Student%20Data%20ML%20Jan%20(Responses)%20-%20Form%20responses%201.tsv','\t')
tsv_data
# Out:
#               Timestamp                       Name  \
# 0   30/01/2020 15:00:07              Sai Naga Raju
# 1   30/01/2020 15:00:20                   R deepak
# 2   30/01/2020 15:00:23              P K CHAITANYA
# 3   30/01/2020 15:00:25                 B SRIKANTH
# 4   30/01/2020 15:00:28           Himaja cherukuri
# 5   30/01/2020 15:00:28              M.Geethanjali
# 6   30/01/2020 15:00:33                  M.Nikhita
# 7   30/01/2020 15:00:37           DASARI PAVAN SAI
# 8   30/01/2020 15:00:39              B Jagan Mohan
# 9   30/01/2020 15:00:41          k.parameswara rao
# 10  30/01/2020 15:00:43           B.Ravindra kumar
# 11  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 12  30/01/2020 15:00:45      Thatavarti kavya sree
# 13  30/01/2020 15:01:10               Harish Bandi
# 14  30/01/2020 15:01:16     M.Bhavani Sankar Reddy
# 15  30/01/2020 15:01:24             Devendra Kumar
# 16  30/01/2020 15:01:35                    M.Ramya
# ...

# %%
excel_data = pd.read_excel('C://Users/Ravi/Downloads/Student Data ML Jan (Responses).xlsx')
excel_data
# Out:
#                  Timestamp                       Name  \
# 0  2020-01-30 15:00:06.734              Sai Naga Raju
# 1  2020-01-30 15:00:19.555                   R deepak
# 2  2020-01-30 15:00:23.470              P K CHAITANYA
# 3  2020-01-30 15:00:25.434                 B SRIKANTH
# 4  2020-01-30 15:00:27.759           Himaja cherukuri
# 5  2020-01-30 15:00:28.333              M.Geethanjali
# 6  2020-01-30 15:00:32.644                  M.Nikhita
# 7  2020-01-30 15:00:36.728           DASARI PAVAN SAI
# 8  2020-01-30 15:00:39.347              B Jagan Mohan
# 9  2020-01-30 15:00:40.676          k.parameswara rao
# 10 2020-01-30 15:00:42.915           B.Ravindra kumar
# 11 2020-01-30 15:00:44.077        P.M.S.Bhargav Kumar
# 12 2020-01-30 15:00:44.555      Thatavarti kavya sree
# 13 2020-01-30 15:01:10.442               Harish Bandi
# 14 2020-01-30 15:01:15.898     M.Bhavani Sankar Reddy
# 15 2020-01-30 15:01:24.277             Devendra Kumar
# ...

# %%
excel_data.head()
# Out:
#                 Timestamp              Name                            MailId  \
# 0 2020-01-30 15:00:06.734     Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 1 2020-01-30 15:00:19.555          R deepak            deepakrella9@gmail.com
# 2 2020-01-30 15:00:23.470     P K CHAITANYA              chaitu1495@gmail.com
# 3 2020-01-30 15:00:25.434        B SRIKANTH           srikanthbisai@gmail.com
# 4 2020-01-30 15:00:27.759  Himaja cherukuri         himajacherukuri@gmail.com
#
#   Branch Qualification    RollNumber
# 0     IT        B.Tech    161FA07039
# 1    MCA            PG  121722501019
# 2    MCA            PG  121722501015
# 3    MCA            PG  121722501002
# 4    cse         BTech    161fa04079

# %% [markdown]
# Slicing

# %%
data
# Out:
#               Timestamp                       Name  \
# 0   30/01/2020 15:00:07              Sai Naga Raju
# 1   30/01/2020 15:00:20                   R deepak
# 2   30/01/2020 15:00:23              P K CHAITANYA
# 3   30/01/2020 15:00:25                 B SRIKANTH
# 4   30/01/2020 15:00:28           Himaja cherukuri
# 5   30/01/2020 15:00:28              M.Geethanjali
# 6   30/01/2020 15:00:33                  M.Nikhita
# 7   30/01/2020 15:00:37           DASARI PAVAN SAI
# 8   30/01/2020 15:00:39              B Jagan Mohan
# 9   30/01/2020 15:00:41          k.parameswara rao
# 10  30/01/2020 15:00:43           B.Ravindra kumar
# 11  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 12  30/01/2020 15:00:45      Thatavarti kavya sree
# 13  30/01/2020 15:01:10               Harish Bandi
# 14  30/01/2020 15:01:16     M.Bhavani Sankar Reddy
# 15  30/01/2020 15:01:24             Devendra Kumar
# 16  30/01/2020 15:01:35                    M.Ramya
# ...

# %%
data[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-80a4aab09c73> in <module>
# ----> 1 data[0]
#
# NameError: name 'data' is not defined

# %% [markdown]
# - position based indexing--->iloc
# - label based indexing

# %%
data.iloc[0]
# Out:
# Timestamp                     30/01/2020 15:00:07
# Name                                Sai Naga Raju
# MailId           sainagarajusakhamuri99@gmail.com
# Branch                                         IT
# Qualification                              B.Tech
# RollNumber                             161FA07039
# Name: 0, dtype: object

# %%
data.iloc[0:1]
# Out:
#              Timestamp           Name                            MailId  \
# 0  30/01/2020 15:00:07  Sai Naga Raju  sainagarajusakhamuri99@gmail.com
#
#   Branch Qualification  RollNumber
# 0     IT        B.Tech  161FA07039

# %%
data.iloc[0:6:2]
# Out:
#              Timestamp              Name                            MailId  \
# 0  30/01/2020 15:00:07     Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 2  30/01/2020 15:00:23     P K CHAITANYA              chaitu1495@gmail.com
# 4  30/01/2020 15:00:28  Himaja cherukuri         himajacherukuri@gmail.com
#
#   Branch Qualification    RollNumber
# 0     IT        B.Tech    161FA07039
# 2    MCA            PG  121722501015
# 4    cse         BTech    161fa04079

# %%
data.iloc[0:6:2,1:3]
# Out:
#                Name                            MailId
# 0     Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 2     P K CHAITANYA              chaitu1495@gmail.com
# 4  Himaja cherukuri         himajacherukuri@gmail.com

# %%
data.iloc[-1]
# Out:
# Timestamp           30/01/2020 15:07:38
# Name                 SAIKUMAR MANIKONDA
# MailId            saikumarm64@gmail.com
# Branch           Automobile Engineering
# Qualification                       B.E
# RollNumber                 245112769310
# Name: 25, dtype: object

# %%
data.iloc[-2:,-2:]
# Out:
#    Qualification    RollNumber
# 24        B.TECH    161FA07025
# 25           B.E  245112769310

# %%
#rows(7,11,15)
#columns()last 3
data.iloc[7:16:4,-3]
# Out:
# 7     Information Technology
# 11          Computer Science
# 15                       ECE
# Name: Branch, dtype: object

# %%
data.loc[0]
# Out:
# Timestamp                     30/01/2020 15:00:07
# Name                                Sai Naga Raju
# MailId           sainagarajusakhamuri99@gmail.com
# Branch                                         IT
# Qualification                              B.Tech
# RollNumber                             161FA07039
# Name: 0, dtype: object

# %%
data.loc[0:0]
# Out:
#              Timestamp           Name                            MailId  \
# 0  30/01/2020 15:00:07  Sai Naga Raju  sainagarajusakhamuri99@gmail.com
#
#   Branch Qualification  RollNumber
# 0     IT        B.Tech  161FA07039

# %%
data.loc[0:15:3]
# Out:
#               Timestamp                   Name  \
# 0   30/01/2020 15:00:07          Sai Naga Raju
# 3   30/01/2020 15:00:25             B SRIKANTH
# 6   30/01/2020 15:00:33              M.Nikhita
# 9   30/01/2020 15:00:41      k.parameswara rao
# 12  30/01/2020 15:00:45  Thatavarti kavya sree
# 15  30/01/2020 15:01:24         Devendra Kumar
#
#                               MailId Branch Qualification    RollNumber
# 0   sainagarajusakhamuri99@gmail.com     IT        B.Tech    161FA07039
# 3            srikanthbisai@gmail.com    MCA            PG  121722501002
# 6             muvvanikhita@gmail.com    CSE        B.Tech    161FA04106
# 9     parameshkarumuri1997@gmail.com    MCA            PG  121722501011
# 12         kavyathatavarti@gmail.com     IT        B.Tech    161FA07050
# 15          devendra108148@gmail.com    ECE        B.Tech    14F41A0461

# %%
data.loc[0:4:2,'Name':'MailId']
# Out:
#                Name                            MailId
# 0     Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 2     P K CHAITANYA              chaitu1495@gmail.com
# 4  Himaja cherukuri         himajacherukuri@gmail.com

# %%
data.loc[0:4:2,'Name':'MailId']
# Out:
#                Name                            MailId
# 0     Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 2     P K CHAITANYA              chaitu1495@gmail.com
# 4  Himaja cherukuri         himajacherukuri@gmail.com

# %%
data.loc[25:24:-1,'Name':'RollNumber']
# Out:
#                   Name                       MailId                  Branch  \
# 25  SAIKUMAR MANIKONDA        saikumarm64@gmail.com  Automobile Engineering
# 24     SAI TEJA JALADI  saitejajaladi2000@gmail.com                     I.T
#
#    Qualification    RollNumber
# 25           B.E  245112769310
# 24        B.TECH    161FA07025

# %%
b='@'
for i in data['MailId']:
    for j in i:
        if j == b :
            print(i)
# Out:
# sainagarajusakhamuri99@gmail.com
# deepakrella9@gmail.com
# chaitu1495@gmail.com
# srikanthbisai@gmail.com
# himajacherukuri@gmail.com
# geethamuppuri@gmail.com
# muvvanikhita@gmail.com
# pavandasari226@gmail.com
# bjaganmohan24@gmail.com
# parameshkarumuri1997@gmail.com
# ravindrakumarroyal12@gmail.com
# bhargavperumalla123@gmail.com
# kavyathatavarti@gmail.com
# harishbandi12@gmail.com
# bhavanisankar5758@gmail.com
# devendra108148@gmail.com
# ramya.marripoodi@gmail.com
# tvnagajyothi@gmail.com
# p.anandalakshmi@gmail.com
# saikamavarapu@gmail.com
# ali95asghar@gmail.com
# 121822502016@gitam.in
# duppatijayanaveen@gmail.com
# vikramsabbavarapu60@gmail.com
# saitejajaladi2000@gmail.com
# saikumarm64@gmail.com
